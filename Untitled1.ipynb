# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Downloads/car data.xls')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df1=pd.read_csv('Downloads/car data.xls')

# %%
# Python3 code to remove whitespace
def remove(string):
    return string.replace(" ", "_")

# Driver Program
#string = ' g e e k '
#print(remove(string))

# %%
df1=pd.read_csv('Downloads/car data.xls')
l=[]
for i in list(df1['Car_Name']):
    l.append(remove(i))
print(l)
# Out:
# ['ritz', 'sx4', 'ciaz', 'wagon_r', 'swift', 'vitara_brezza', 'ciaz', 's_cross', 'ciaz', 'ciaz', 'alto_800', 'ciaz', 'ciaz', 'ertiga', 'dzire', 'ertiga', 'ertiga', 'ertiga', 'wagon_r', 'sx4', 'alto_k10', 'ignis', 'sx4', 'alto_k10', 'wagon_r', 'swift', 'swift', 'swift', 'alto_k10', 'ciaz', 'ritz', 'ritz', 'swift', 'ertiga', 'dzire', 'sx4', 'dzire', '800', 'alto_k10', 'sx4', 'baleno', 'alto_k10', 'sx4', 'dzire', 'omni', 'ciaz', 'ritz', 'wagon_r', 'ertiga', 'ciaz', 'fortuner', 'fortuner', 'innova', 'fortuner', 'innova', 'corolla_altis', 'etios_cross', 'corolla_altis', 'etios_g', 'fortuner', 'corolla_altis', 'etios_cross', 'fortuner', 'fortuner', 'fortuner', 'etios_liva', 'innova', 'fortuner', 'corolla_altis', 'corolla_altis', 'etios_liva', 'corolla_altis', 'corolla_altis', 'etios_liva', 'etios_cross', 'etios_g', 'corolla_altis', 'corolla', 'corolla_altis', 'fortuner', 'corolla_altis', 'etios_gd', 'innova', 'innova', 'innova', 'camry', 'land_cruiser', 'corolla_altis', 'etios_liva', 'etios
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()
df['Car_Name'] = ord_enc.fit_transform(df[['Car_Name']])

# %%
dic={}
for i in range(df['Car_Name'].shape[0]):
    dic[l[i]]=df['Car_Name'].iloc[i]
print(dic)
# Out:
# {'ritz': 90.0, 'sx4': 93.0, 'ciaz': 68.0, 'wagon_r': 96.0, 'swift': 92.0, 'vitara_brezza': 95.0, 's_cross': 91.0, 'alto_800': 62.0, 'ertiga': 76.0, 'dzire': 73.0, 'alto_k10': 63.0, 'ignis': 85.0, '800': 0.0, 'baleno': 65.0, 'omni': 89.0, 'fortuner': 81.0, 'innova': 86.0, 'corolla_altis': 71.0, 'etios_cross': 77.0, 'etios_g': 78.0, 'etios_liva': 80.0, 'corolla': 70.0, 'etios_gd': 79.0, 'camry': 67.0, 'land_cruiser': 88.0, 'Royal_Enfield_Thunder_500': 49.0, 'UM_Renegade_Mojave': 56.0, 'KTM_RC200': 42.0, 'Bajaj_Dominar_400': 11.0, 'Royal_Enfield_Classic_350': 46.0, 'KTM_RC390': 43.0, 'Hyosung_GT250R': 40.0, 'Royal_Enfield_Thunder_350': 48.0, 'KTM_390_Duke_': 41.0, 'Mahindra_Mojo_XT300': 44.0, 'Bajaj_Pulsar_RS200': 17.0, 'Royal_Enfield_Bullet_350': 45.0, 'Royal_Enfield_Classic_500': 47.0, 'Bajaj_Avenger_220': 6.0, 'Bajaj_Avenger_150': 4.0, 'Honda_CB_Hornet_160R': 32.0, 'Yamaha_FZ_S_V_2.0': 60.0, 'Yamaha_FZ_16': 58.0, 'TVS_Apache_RTR_160': 51.0, 'Bajaj_Pulsar_150': 14.0, 'Honda_CBR_150': 
# ...

# %%
df.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      90.0  2014           3.35           5.59       27000    Petrol
# 1      93.0  2013           4.75           9.54       43000    Diesel
# 2      68.0  2017           7.25           9.85        6900    Petrol
# 3      96.0  2011           2.85           4.15        5200    Petrol
# 4      92.0  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
print('no.of rows',df.shape[0])
print('no.of rows',df.shape[1])
# Out:
# no.of rows 301
# no.of rows 9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    float64
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.dtypes
# Out:
# Car_Name         float64
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df.describe()
# Out:
#          Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count  301.000000   301.000000     301.000000     301.000000     301.000000
# mean    62.571429  2013.627907       4.661296       7.628472   36947.205980
# std     25.573535     2.891554       5.082812       8.644115   38886.883882
# min      0.000000  2003.000000       0.100000       0.320000     500.000000
# 25%     47.000000  2012.000000       0.900000       1.200000   15000.000000
# 50%     69.000000  2014.000000       3.600000       6.400000   32000.000000
# 75%     82.000000  2016.000000       6.000000       9.900000   48767.000000
# max     97.000000  2018.000000      35.000000      92.600000  500000.000000
#
#             Owner
# count  301.000000
# mean     0.043189
# std      0.247915
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      3.000000

# %% [markdown]
# # Data Preprocessing

# %%
date_time=datetime.datetime.now()
date_time
# Out:
# datetime.datetime(2023, 6, 19, 16, 31, 49, 166970)

# %%
df['age']=date_time.year-df['Year']

# %%
df.head(2)
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      90.0  2014           3.35           5.59       27000    Petrol
# 1      93.0  2013           4.75           9.54       43000    Diesel
#
#   Seller_Type Transmission  Owner  age
# 0      Dealer       Manual      0    9
# 1      Dealer       Manual      0   10

# %%
df.drop('Year',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0      90.0           3.35           5.59       27000    Petrol      Dealer
# 1      93.0           4.75           9.54       43000    Diesel      Dealer
#
#   Transmission  Owner  age
# 0       Manual      0    9
# 1       Manual      0   10

# %%
df['Selling_Price']=df['Selling_Price']*100000
df['Present_Price']=df['Present_Price']*100000

# %%
df.head(2)
# Out:
#    Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0      90.0       335000.0       559000.0       27000    Petrol      Dealer
# 1      93.0       475000.0       954000.0       43000    Diesel      Dealer
#
#   Transmission  Owner  age
# 0       Manual      0    9
# 1       Manual      0   10

# %%
df['Selling_Price']=df['Selling_Price'].astype('int64')
df['Present_Price']=df['Present_Price'].astype('int64')
df.dtypes
# Out:
# Car_Name         float64
# Selling_Price      int64
# Present_Price      int64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# age                int64
# dtype: object

# %% [markdown]
# # Outlier Removal

# %%
sns.boxplot(df['Selling_Price'])
# Out:
# <AxesSubplot:xlabel='Selling_Price'>

# %%
sorted(df['Selling_Price'],reverse=True)
# Out:
# [3500000,
#  3300000,
#  2350000,
#  2300000,
#  2300000,
#  2300000,
#  2075000,
#  1998999,
#  1975000,
#  1875000,
#  1800000,
#  1700000,
#  1600000,
#  1490000,
#  1473000,
#  1450000,
#  1425000,
#  1290000,
#  1250000,
#  1175000,
#  1150000,
#  1145000,
#  1125000,
#  1125000,
#  1125000,
#  1090000,
#  1025000,
#  1011000,
#  969999,
#  965000,
#  950000,
#  925000,
#  925000,
#  925000,
#  915000,
#  910000,
#  899000,
#  875000,
#  865000,
#  855000,
#  850000,
#  840000,
#  840000,
#  835000,
#  825000,
#  825000,
#  790000,
#  775000,
#  775000,
#  775000,
#  750000,
#  750000,
#  750000,
#  745000,
#  745000,
#  745000,
#  740000,
#  725000,
#  725000,
#  720000,
#  705000,
#  695000,
#  685000,
#  675000,
#  670000,
#  660000,
#  650000,
#  650000,
#  645000,
#  640000,
#  625000,
#  625000,
#  615000,
#  610000,
#  600000,
#  600000,
#  600000,
#  600000,
#  595000,
#  595000,
#  590000,
#  585000,
#  585000,
#  580000,
#  575000,
#  575000,
#  565000,
#  550000,
# ...

# %%
df[(df['Selling_Price']>=3300000 )&(df['Selling_Price']<=3500000)]
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 64      81.0        3300000        3622999        6000    Diesel      Dealer
# 86      88.0        3500000        9260000       78000    Diesel      Dealer
#
#    Transmission  Owner  age
# 64    Automatic      0    6
# 86       Manual      0   13

# %%
df=df[~(df['Selling_Price']>=3300000 )&(df['Selling_Price']<=3500000)]

# %%
df.shape
# Out:
# (299, 9)

# %% [markdown]
# # Encoding the categorical columns

# %%
df['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     58
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df['Fuel_Type']=df['Fuel_Type'].map({'Petrol':0,'Diesel':1,'CNG':2})

# %%
df['Fuel_Type'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Seller_Type']=df['Seller_Type'].map({'Dealer':0,'Individual':1})

# %%
df['Seller_Type'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Transmission']=df['Transmission'].map({'Manual':0,'Automatic':1})

# %%
df['Transmission'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Car_Name'].unique()
# Out:
# array([90., 93., 68., 96., 92., 95., 91., 62., 76., 73., 63., 85.,  0.,
#        65., 89., 81., 86., 71., 77., 78., 80., 70., 79., 67., 49., 56.,
#        42., 11., 46., 43., 40., 48., 41., 44., 17., 45., 47.,  6.,  4.,
#        32., 60., 58., 51., 14., 37., 20.,  7.,  5., 57., 12., 15., 52.,
#        26., 16., 61., 31., 54., 38.,  8., 28.,  1., 25., 34., 59., 13.,
#         2., 35., 22., 39., 30., 53., 23., 27., 33.,  9., 50., 55., 36.,
#        21., 29., 10., 24., 19., 18.,  3., 84., 82., 83., 75., 97., 74.,
#        72., 94., 69., 66., 64., 87.])

# %%
df.corr()
# Out:
#                Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# Car_Name       1.000000       0.530069       0.545047    0.063205   0.365944
# Selling_Price  0.530069       1.000000       0.880358    0.026114   0.502783
# Present_Price  0.545047       0.880358       1.000000    0.222983   0.454030
# Kms_Driven     0.063205       0.026114       0.222983    1.000000   0.167606
# Fuel_Type      0.365944       0.502783       0.454030    0.167606   1.000000
# Seller_Type   -0.829087      -0.593836      -0.600807   -0.101256  -0.347922
# Transmission   0.055747       0.375638       0.421225    0.173079   0.068618
# Owner         -0.080401      -0.092628       0.019682    0.089639  -0.054174
# age           -0.018763      -0.273127       0.024282    0.520899  -0.055095
#
#                Seller_Type  Transmission     Owner       age
# Car_Name         -0.829087      0.055747 -0.080401 -0.018763
# Selling_Price    -0.593836      0.375638 -0.092628 -0.273127
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# # Correlation

# %%
corrmat=df.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
df.head(2)
# Out:
#    Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0      90.0         335000         559000       27000          0            0
# 1      93.0         475000         953999       43000          1            0
#
#    Transmission  Owner  age
# 0             0      0    9
# 1             0      0   10

# %%
# splitting dependent and independent features
X=df.drop(['Selling_Price'],axis=1)
y=df.loc[:,'Selling_Price']

# %%
X.head(2)
# Out:
#    Car_Name  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0      90.0         559000       27000          0            0             0
# 1      93.0         953999       43000          1            0             0
#
#    Owner  age
# 0      0    9
# 1      0   10

# %%
y.head(3)
# Out:
# 0    335000
# 1    475000
# 2    725000
# Name: Selling_Price, dtype: int64

# %% [markdown]
# # Feature importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.08421066 0.47129349 0.03032991 0.0780051  0.18239096 0.05316435
#  0.0006738  0.09993172]

# %%
# to see in graphical representation
feat_importances=pd.Series(model.feature_importances_,index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (239, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()

# %%
# Hyper Parameters
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
# Randomized search CV

# Number of Trees in Random Forest
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]

# Number of Features toconsider in each split
max_features=['auto','sqrt']

# maximum number of levels in Tree
max_depth=[int(x) for x in np.linspace(5,30,num=6)]

# Minimum number of samples required to split a node
min_samples_split=[2,5,10,15,100]

# Minimum number of samples required at each leaf node
min_samples_leaf=[1,2,5,10]

# %%
# Create the random grid
random_grid={'n_estimators':n_estimators,
            'max_features':max_features,
             'max_depth':max_depth,
             'min_samples_split':min_samples_split,
             'min_samples_leaf':min_samples_leaf
            }
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rf_random=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,scoring='neg_mean_squared_error',n_iter=10,cv=5,verbose=2,random_state=42,n_jobs=1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.2s
# ...

# %%
predictions=rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 371137.94 ,   93832.951,   62526.   ,  122790.689,  366875.98 ,
#         452779.989,   21956.   ,  107741.97 ,  808086.97 ,  963459.994,
#          62880.993,   32410.   ,  562574.917,  507746.996,  278459.932,
#         105374.882,  369249.996,  608416.995,  539803.958,  262942.959,
#         461364.807, 1620129.979,  535967.995,   71709.986,  596765.996,
#          64581.997, 1912181.989,  556164.98 ,  410089.819,  867276.984,
#         534722.995,  532971.659,   47645.   ,  419932.962,  329221.948,
#         687243.994,  682288.999,   44340.997,   58787.999,  831826.999,
#          48544.993, 2171872.92 ,   63925.   ,  691019.993,   46191.995,
#         464002.983,  401886.956,  960866.928, 1015558.877,  608670.989,
#         116888.912,  385716.914,  520969.999,  773558.864,  308472.899,
#         645359.995,  540807.986,   45248.   ,  137227.944,  791662.998])

# %%
sns.distplot(y_test-predictions)
# Out:
# <AxesSubplot:xlabel='Selling_Price', ylabel='Density'>

# %%
import pickle
file=open('Car_Price_prediction_model.pkl','wb')
pickle.dump(rf_random,file)

# %%
X_train.head(2)
# Out:
#      Car_Name  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 173       2.0          51000        1300          0            1
# 117      49.0         190000       14000          0            1
#
#      Transmission  Owner  age
# 173             1      0    6
# 117             0      0    8

# %%
import pickle
forest = open('Car_Price_prediction_model.pkl','rb')
model = pickle.load(forest)

# %%
prediction=model.predict([[69.0,990000,54242,0,0,0,0,10]])
int(prediction[0])
# Out:
# 507746

# %%
df.head(256)
# Out:
#      Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0        90.0         335000         559000       27000          0
# 1        93.0         475000         953999       43000          1
# 2        68.0         725000         985000        6900          0
# 3        96.0         285000         415000        5200          0
# 4        92.0         459999         687000       42450          1
# ..        ...            ...            ...         ...        ...
# 253      69.0         720000         990000       48000          1
# 254      69.0         525000         990000       54242          0
# 255      66.0         300000         535000       53675          0
# 256      69.0        1025000        1360000       49562          0
# 257      69.0         850000        1360000       40324          0
#
#      Seller_Type  Transmission  Owner  age
# 0              0             0      0    9
# 1              0             0      0   10
# ...

# %%
l
# Out:
# 97
